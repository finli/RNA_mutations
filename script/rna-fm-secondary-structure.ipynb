# %% [raw]
# !git clone https://github.com/ml4bio/RNA-FM.git
# !cd ./RNA-FM
# !pip install ./RNA-FM --no-deps
# !pip install ptflops

# %% [markdown]
# # RNA-FM pair-wise connectivity model

# %%
import torch
import fm

path= "/data/home/chenjiayang/projects/RNA-FM/redevelop/pretrained/Models/SS/RNA-FM-ResNet_PDB-All.pth"
model, alphabet = fm.downstream.build_rnafm_resnet(type="ss") #, model_location=path)
# Out:
# tensor([[[  0.1480,  -4.8981, -11.4271,  ..., -12.4071,  -9.5562,  -6.0911],
#          [ -4.8981,   0.1253, -11.7829,  ..., -15.3051,  -9.5378, -10.4153],
#          [-11.4271, -11.7829,  -6.3015,  ..., -15.4624, -14.3296, -10.6362],
#          ...,
#          [-12.4071, -15.3051, -15.4624,  ...,  -8.3671, -12.9738, -10.4467],
#          [ -9.5562,  -9.5378, -14.3296,  ..., -12.9738,  -5.4848,  -9.9814],
#          [ -6.0911, -10.4153, -10.6362,  ..., -10.4467,  -9.9814,  -5.6822]]])
# torch.Size([1, 45, 45])

# %%
def predict_secondary_structure(seq):
    # model, alphabet = fm.downstream.build_rnafm_resnet(type="ss")
    batch_converter = alphabet.get_batch_converter()
    model.eval()  # disables dropout for deterministic results
    
    data = [("RNA1", seq.replace("T", "U"))]
    
    # Prepare data
    batch_labels, batch_strs, batch_tokens = batch_converter(data)

    input = {
        "description": batch_labels,
        "token": batch_tokens
    }

    # Secondary Structure Prediction (on CPU)
    with torch.no_grad():
        results = model(input)
    
    ss_prob_map = results["r-ss"]
    ss_prob = torch.sigmoid(ss_prob_map)[0]
    
    #print(ss_prob_map)
    #print(ss_prob_map.shape)
    return ss_prob

# Example usage
#ss_prob_map = predict_secondary_structure("GAUUCGACGGGGACUUCGGUCCUCGGACGCGGGUUCGAUUCCCGC")
ss_prob_map = predict_secondary_structure("GAUUCGACGGGGACUUCGGUCCUCGGACGCGGGUUCGAUUCCCGC")

# %%
ss_prob_map
# Out:
# tensor([[5.3692e-01, 7.4053e-03, 1.0896e-05,  ..., 4.0896e-06, 7.0754e-05,
#          2.2578e-03],
#         [7.4053e-03, 5.3129e-01, 7.6337e-06,  ..., 2.2547e-07, 7.2072e-05,
#          2.9971e-05],
#         [1.0896e-05, 7.6337e-06, 1.8302e-03,  ..., 1.9266e-07, 5.9803e-07,
#          2.4029e-05],
#         ...,
#         [4.0896e-06, 2.2547e-07, 1.9266e-07,  ..., 2.3234e-04, 2.3203e-06,
#          2.9042e-05],
#         [7.0754e-05, 7.2072e-05, 5.9803e-07,  ..., 2.3203e-06, 4.1321e-03,
#          4.6252e-05],
#         [2.2578e-03, 2.9971e-05, 2.4029e-05,  ..., 2.9042e-05, 4.6252e-05,
#          3.3944e-03]])

# %% [markdown]
# # Convert pairwise probability to dot bracket notation

# %%
import numpy as np

def pairwise_prob_to_dot_bracket(prob_matrix, threshold=0.5):
    """
    Convert a pairwise probability matrix into a Dot-Bracket notation.
    
    Args:
    - prob_matrix (np.ndarray): A NxN matrix of base-pair probabilities.
    - threshold (float): Minimum probability to consider a valid base pair.
    
    Returns:
    - str: Dot-Bracket notation for the RNA secondary structure.
    """
    n = len(prob_matrix)
    structure = ["." for _ in range(n)]  # Start with unpaired bases
    paired = set()
    
    # Flatten the upper-triangular part of the matrix to sort by probability
    pairs = [(i, j, prob_matrix[i, j]) for i in range(n) for j in range(i+1, n)]
    pairs = sorted(pairs, key=lambda x: x[2], reverse=True)  # Sort by probability (high to low)
    
    # Greedy pairing based on the highest probability
    for i, j, prob in pairs:
        if prob < threshold:
            break  # Stop if the probability is too low
        if i not in paired and j not in paired:  # Ensure valid pairing
            structure[i] = "("
            structure[j] = ")"
            paired.add(i)
            paired.add(j)

    return "".join(structure)

# Example usage
prob_matrix = np.array([
    [0.0, 0.9, 0.1, 0.0],
    [0.9, 0.0, 0.8, 0.2],
    [0.1, 0.8, 0.0, 0.7],
    [0.0, 0.2, 0.7, 0.0]
])

prob_matrix = torch.sigmoid(ss_prob_map)[0]

dot_bracket = pairwise_prob_to_dot_bracket(prob_matrix, threshold=0.95)
print(dot_bracket)  # Output: "(())." (Example, depends on input)
# Out:
# (..(..(((((((((..)))))))))).((((((..))..)))))

# %% [markdown]
# # RNA Structural Annotation Using DSSR-like Labels
# To annotate each nucleotide position with a DSSR-like label, we categorize them as:
#
# - Stem (S) → Paired bases in a helix (( )).
#
# - Hairpin loop (H) → Unpaired bases enclosed by a single closing pair.
#
# - Bulge (B) → Unpaired bases interrupting a stem on one side.
#
# - Internal Loop (I) → Unpaired bases interrupting a stem on both sides.
#
# - Multiloop (M) → Unpaired bases with multiple branching stems.
#
# - Unstructured (U) → Unpaired bases not in any specific loop.

# %%
import numpy as np

def annotate_rna_structure(dot_bracket):
    """
    Annotate RNA secondary structure with DSSR-like labels.

    Args:
    - dot_bracket (str): Dot-Bracket notation of RNA structure.

    Returns:
    - list: Labels for each nucleotide position.
    """
    n = len(dot_bracket)
    labels = ["U"] * n  # Default to unstructured
    stack = []
    pairs = {}

    # Step 1: Identify base pairs using a stack
    for i, char in enumerate(dot_bracket):
        if char == "(":
            stack.append(i)
        elif char == ")":
            if stack:
                j = stack.pop()
                pairs[i] = j
                pairs[j] = i

    # Step 2: Identify structural elements
    sorted_pairs = sorted(pairs.items())
    
    # Annotate stems
    stems = []
    stem = []
    for i, j in sorted_pairs:
        if stem and i == stem[-1][0] + 1 and j == stem[-1][1] - 1:
            stem.append((i, j))
        else:
            if len(stem) > 1:
                stems.append(stem)
            stem = [(i, j)]
    if len(stem) > 1:
        stems.append(stem)

    for stem in stems:
        for i, j in stem:
            labels[i] = "S"  # Mark as stem
            labels[j] = "S"

    # Annotate loops, bulges, and internal loops
    for stem in stems:
        first, last = stem[0][0], stem[-1][1]
        loop_region = dot_bracket[first + 1:last]

        if "(" not in loop_region and ")" not in loop_region:
            for i in range(first + 1, last):
                labels[i] = "H"  # Hairpin Loop
        else:
            left_unpaired = [i for i in range(first + 1, last) if dot_bracket[i] == "."]
            right_unpaired = [i for i in range(first + 1, last) if dot_bracket[i] == "."]

            if len(left_unpaired) > 0 and len(right_unpaired) > 0:
                for i in left_unpaired + right_unpaired:
                    labels[i] = "I"  # Internal Loop
            elif len(left_unpaired) > 0 or len(right_unpaired) > 0:
                for i in left_unpaired + right_unpaired:
                    labels[i] = "B"  # Bulge

    # Detect multiloops (Regions with multiple stems connecting)
    opening_brackets = set(pairs.values())
    for i, char in enumerate(dot_bracket):
        if char == "." and i > 0 and i < n - 1:
            if dot_bracket[i - 1] in "(.)" and dot_bracket[i + 1] in "(.)":
                if dot_bracket[i - 1] == "(" or dot_bracket[i + 1] == ")":
                    labels[i] = "M"  # Multiloop

    return labels

# Example usage
dot_bracket = "(((...)))..(((..)))"
labels = annotate_rna_structure(dot_bracket)
print("".join(labels))
# Out:
# SSSMIMSSSUUSSSMMSSS

# %% [markdown]
# # Read in Fasta file

# %%
def read_fasta(file_path):
    sequences = {}
    with open(file_path, 'r') as file:
        sequence_name = None
        sequence_data = []
        
        for line in file:
            line = line.strip()
            if line.startswith(">"):  # header line
                if sequence_name:  # Save the previous sequence
                    sequences[sequence_name] = ''.join(sequence_data)
                sequence_name = line[1:]  # Remove ">" from the header
                sequence_data = []  # Reset sequence data
            else:
                sequence_data.append(line)
        
        if sequence_name:  # Save the last sequence
            sequences[sequence_name] = ''.join(sequence_data)

    return sequences

# Example usage:
file_path = "/Users/rkwan/Downloads/3d_banana/result/transcript.fasta"
sequences = read_fasta(file_path)

# %% [markdown]
# # Process the workflow

# %%
total_sequences = len(sequences)

with open("/Users/rkwan/Downloads/3d_banana/result/ss_features.fasta", "w") as file:
    counter = 0
    for sequence_name, sequence in sequences.items():
        #if counter >= 5:
        #    break
            
        # Print progress
        print(f"Processing: {sequence_name} {counter + 1} / {total_sequences} sequences")
            
        #print(f">{sequence_name}\n{sequence}")
        #print(f">{sequence_name}")
        #print(f">{sequence}")
        file.write(f">{sequence_name}\n")
        counter += 1

        try:
            # Call the prediction function and get the secondary structure
            ss_prob_map = predict_secondary_structure(sequence)
            dot_bracket = pairwise_prob_to_dot_bracket(ss_prob_map, threshold=0.95)
            labels = annotate_rna_structure(dot_bracket)

            # Write the labels to the file
            file.write("".join(labels) + "\n")
        
        except Exception as e:
            # If an error occurs, print the error and skip to the next sequence
            print(f"Error processing {sequence_name}: {e}")
            continue
# Out:
# Processing: 1 / 398 sequences
# Processing: 2 / 398 sequences
# Processing: 3 / 398 sequences
# Processing: 4 / 398 sequences
# Processing: 5 / 398 sequences
# Processing: 6 / 398 sequences
# Processing: 7 / 398 sequences
# Processing: 8 / 398 sequences
# Processing: 9 / 398 sequences
# Processing: 10 / 398 sequences
# Processing: 11 / 398 sequences
# Processing: 12 / 398 sequences
# Processing: 13 / 398 sequences
# Processing: 14 / 398 sequences
# Processing: 15 / 398 sequences
# Processing: 16 / 398 sequences
# Processing: 17 / 398 sequences
# Processing: 18 / 398 sequences
# Processing: 19 / 398 sequences
# Processing: 20 / 398 sequences
# Processing: 21 / 398 sequences
# Error processing ENST00000828396: index out of range in self
# Processing: 22 / 398 sequences
# Processing: 23 / 398 sequences
# Processing: 24 / 398 sequences
# Processing: 25 / 398 sequences
# Processing: 26 / 398 sequences
# Processing: 27 / 398 sequences
# Processing: 28 / 398 sequences
# Processing: 29 / 398 sequences
# Error processing ENST00000444815: index out of range in self
# Processing: 30 / 398 sequences
# Processing: 31 / 398 sequences
# Processing: 32 / 398 sequences
# Processing: 33 / 398 sequences
# Error processing ENST00000728237: index out of range in self
# Processing: 34 / 398 sequences
# Processing: 35 / 398 sequences
# Processing: 36 / 398 sequences
# Error processing ENST00000670451: index out of range in self
# Processing: 37 / 398 sequences
# Error processing ENST00000669353: index out of range in self
# Processing: 38 / 398 sequences
# Error processing ENST00000660783: index out of range in self
# Processing: 39 / 398 sequences
# Error processing ENST00000659938: index out of range in self
# Processing: 40 / 398 sequences
# Processing: 41 / 398 sequences
# Processing: 42 / 398 sequences
# Processing: 43 / 398 sequences
# Processing: 44 / 398 sequences
# Processing: 45 / 398 sequences
# Processing: 46 / 398 sequences
# Error processing ENST00000664462: index out of range in self
# Processing: 47 / 398 sequences
# Error processing ENST00000670873: index out of range in self
# Processing: 48 / 398 sequences
# Error processing ENST00000659215: index out of range in self
# Processing: 49 / 398 sequences
# Processing: 50 / 398 sequences
# Processing: 51 / 398 sequences
# Processing: 52 / 398 sequences
# Processing: 53 / 398 sequences
# Processing: 54 / 398 sequences
# Processing: 55 / 398 sequences
# Processing: 56 / 398 sequences
# Processing: 57 / 398 sequences
# Processing: 58 / 398 sequences
# Processing: 59 / 398 sequences
# Processing: 60 / 398 sequences
# Processing: 61 / 398 sequences
# Processing: 62 / 398 sequences
# Error processing ENST00000666808: index out of range in self
# Processing: 63 / 398 sequences
# Processing: 64 / 398 sequences
# Processing: 65 / 398 sequences
# Processing: 66 / 398 sequences
# Processing: 67 / 398 sequences
# Error processing ENST00000670030: index out of range in self
# Processing: 68 / 398 sequences
# Error processing ENST00000653898: index out of range in self
# Processing: 69 / 398 sequences
# Processing: 70 / 398 sequences
# Processing: 71 / 398 sequences
# Processing: 72 / 398 sequences
# Processing: 73 / 398 sequences
# Processing: 74 / 398 sequences
# Processing: 75 / 398 sequences
# Processing: 76 / 398 sequences
# Processing: 77 / 398 sequences
# Processing: 78 / 398 sequences
# Processing: 79 / 398 sequences
# Processing: 80 / 398 sequences
# Processing: 81 / 398 sequences
# Processing: 82 / 398 sequences
# Processing: 83 / 398 sequences
# Processing: 84 / 398 sequences
# Processing: 85 / 398 sequences
# Processing: 86 / 398 sequences
# Error processing ENST00000658094: index out of range in self
# Processing: 87 / 398 sequences
# Error processing ENST00000664546: index out of range in self
# Processing: 88 / 398 sequences
# Error processing ENST00000658611: index out of range in self
# Processing: 89 / 398 sequences
# Error processing ENST00000667139: index out of range in self
# Processing: 90 / 398 sequences
# Error processing ENST00000669465: index out of range in self
# Processing: 91 / 398 sequences
# Error processing ENST00000653918: index out of range in self
# Processing: 92 / 398 sequences
# Error processing ENST00000674972: index out of range in self
# Processing: 93 / 398 sequences
# Error processing ENST00000675486: index out of range in self
# Processing: 94 / 398 sequences
# Processing: 95 / 398 sequences
# Processing: 96 / 398 sequences
# Processing: 97 / 398 sequences
# Processing: 98 / 398 sequences
# Processing: 99 / 398 sequences
# Processing: 100 / 398 sequences
# Processing: 101 / 398 sequences
# Processing: 102 / 398 sequences
# Processing: 103 / 398 sequences
# Processing: 104 / 398 sequences
# Processing: 105 / 398 sequences
# Processing: 106 / 398 sequences
# Processing: 107 / 398 sequences
# Processing: 108 / 398 sequences
# Processing: 109 / 398 sequences
# Processing: 110 / 398 sequences
# Processing: 111 / 398 sequences
# Processing: 112 / 398 sequences
# Processing: 113 / 398 sequences
# Processing: 114 / 398 sequences
# Processing: 115 / 398 sequences
# Processing: 116 / 398 sequences
# Processing: 117 / 398 sequences
# Processing: 118 / 398 sequences
# Processing: 119 / 398 sequences
# Processing: 120 / 398 sequences
# Processing: 121 / 398 sequences
# Processing: 122 / 398 sequences
# Processing: 123 / 398 sequences
# Processing: 124 / 398 sequences
# Processing: 125 / 398 sequences
# Processing: 126 / 398 sequences
# Processing: 127 / 398 sequences
# Processing: 128 / 398 sequences
# Processing: 129 / 398 sequences
# Processing: 130 / 398 sequences
# Processing: 131 / 398 sequences
# Processing: 132 / 398 sequences
# Processing: 133 / 398 sequences
# Processing: 134 / 398 sequences
# Processing: 135 / 398 sequences
# Processing: 136 / 398 sequences
# Processing: 137 / 398 sequences
# Processing: 138 / 398 sequences
# Processing: 139 / 398 sequences
# Processing: 140 / 398 sequences
# Processing: 141 / 398 sequences
# Processing: 142 / 398 sequences
# Processing: 143 / 398 sequences
# Processing: 144 / 398 sequences
# Processing: 145 / 398 sequences
# Processing: 146 / 398 sequences
# Processing: 147 / 398 sequences
# Processing: 148 / 398 sequences
# Processing: 149 / 398 sequences
# Processing: 150 / 398 sequences
# Processing: 151 / 398 sequences
# Processing: 152 / 398 sequences
# Processing: 153 / 398 sequences
# Processing: 154 / 398 sequences
# Processing: 155 / 398 sequences
# Processing: 156 / 398 sequences
# Processing: 157 / 398 sequences
# Processing: 158 / 398 sequences
# Processing: 159 / 398 sequences
# Processing: 160 / 398 sequences
# Processing: 161 / 398 sequences
# Processing: 162 / 398 sequences
# Processing: 163 / 398 sequences
# Processing: 164 / 398 sequences
# Processing: 165 / 398 sequences
# Processing: 166 / 398 sequences
# Processing: 167 / 398 sequences
# Processing: 168 / 398 sequences
# Processing: 169 / 398 sequences
# Processing: 170 / 398 sequences
# Processing: 171 / 398 sequences
# Processing: 172 / 398 sequences
# Processing: 173 / 398 sequences
# Processing: 174 / 398 sequences
# Processing: 175 / 398 sequences
# Processing: 176 / 398 sequences
# Processing: 177 / 398 sequences
# Processing: 178 / 398 sequences
# Processing: 179 / 398 sequences
# Processing: 180 / 398 sequences
# Processing: 181 / 398 sequences
# Processing: 182 / 398 sequences
# Processing: 183 / 398 sequences
# Processing: 184 / 398 sequences
# Processing: 185 / 398 sequences
# Processing: 186 / 398 sequences
# Processing: 187 / 398 sequences
# Processing: 188 / 398 sequences
# Processing: 189 / 398 sequences
# Processing: 190 / 398 sequences
# Processing: 191 / 398 sequences
# Processing: 192 / 398 sequences
# Processing: 193 / 398 sequences
# Processing: 194 / 398 sequences
# Processing: 195 / 398 sequences
# Processing: 196 / 398 sequences
# Processing: 197 / 398 sequences
# Processing: 198 / 398 sequences
# Processing: 199 / 398 sequences
# Processing: 200 / 398 sequences
# Processing: 201 / 398 sequences
# Processing: 202 / 398 sequences
# Processing: 203 / 398 sequences
# Processing: 204 / 398 sequences
# Processing: 205 / 398 sequences
# Processing: 206 / 398 sequences
# Processing: 207 / 398 sequences
# Processing: 208 / 398 sequences
# Processing: 209 / 398 sequences
# Processing: 210 / 398 sequences
# Processing: 211 / 398 sequences
# Processing: 212 / 398 sequences
# Processing: 213 / 398 sequences
# Processing: 214 / 398 sequences
# Processing: 215 / 398 sequences
# Processing: 216 / 398 sequences
# Processing: 217 / 398 sequences
# Processing: 218 / 398 sequences
# Processing: 219 / 398 sequences
# Processing: 220 / 398 sequences
# Processing: 221 / 398 sequences
# Processing: 222 / 398 sequences
# Processing: 223 / 398 sequences
# Processing: 224 / 398 sequences
# Processing: 225 / 398 sequences
# Processing: 226 / 398 sequences
# Processing: 227 / 398 sequences
# Processing: 228 / 398 sequences
# Processing: 229 / 398 sequences
# Processing: 230 / 398 sequences
# Processing: 231 / 398 sequences
# Processing: 232 / 398 sequences
# Processing: 233 / 398 sequences
# Processing: 234 / 398 sequences
# Processing: 235 / 398 sequences
# Processing: 236 / 398 sequences
# Processing: 237 / 398 sequences
# Processing: 238 / 398 sequences
# Processing: 239 / 398 sequences
# Processing: 240 / 398 sequences
# Processing: 241 / 398 sequences
# Processing: 242 / 398 sequences
# Processing: 243 / 398 sequences
# Processing: 244 / 398 sequences
# Processing: 245 / 398 sequences
# Processing: 246 / 398 sequences
# Processing: 247 / 398 sequences
# Processing: 248 / 398 sequences
# Processing: 249 / 398 sequences
# Processing: 250 / 398 sequences
# Processing: 251 / 398 sequences
# Processing: 252 / 398 sequences
# Processing: 253 / 398 sequences
# Processing: 254 / 398 sequences
# Processing: 255 / 398 sequences
# Processing: 256 / 398 sequences
# Processing: 257 / 398 sequences
# Processing: 258 / 398 sequences
# Processing: 259 / 398 sequences
# Processing: 260 / 398 sequences
# Processing: 261 / 398 sequences
# Processing: 262 / 398 sequences
# Processing: 263 / 398 sequences
# Processing: 264 / 398 sequences
# Processing: 265 / 398 sequences
# Processing: 266 / 398 sequences
# Processing: 267 / 398 sequences
# Processing: 268 / 398 sequences
# Processing: 269 / 398 sequences
# Processing: 270 / 398 sequences
# Processing: 271 / 398 sequences
# Processing: 272 / 398 sequences
# Processing: 273 / 398 sequences
# Processing: 274 / 398 sequences
# Processing: 275 / 398 sequences
# Processing: 276 / 398 sequences
# Processing: 277 / 398 sequences
# Processing: 278 / 398 sequences
# Processing: 279 / 398 sequences
# Processing: 280 / 398 sequences
# Processing: 281 / 398 sequences
# Processing: 282 / 398 sequences
# Processing: 283 / 398 sequences
# Processing: 284 / 398 sequences
# Processing: 285 / 398 sequences
# Processing: 286 / 398 sequences
# Processing: 287 / 398 sequences
# Processing: 288 / 398 sequences
# Processing: 289 / 398 sequences
# Processing: 290 / 398 sequences
# Processing: 291 / 398 sequences
# Processing: 292 / 398 sequences
# Processing: 293 / 398 sequences
# Processing: 294 / 398 sequences
# Processing: 295 / 398 sequences
# Processing: 296 / 398 sequences
# Processing: 297 / 398 sequences
# Processing: 298 / 398 sequences
# Processing: 299 / 398 sequences
# Processing: 300 / 398 sequences
# Processing: 301 / 398 sequences
# Processing: 302 / 398 sequences
# Processing: 303 / 398 sequences
# Processing: 304 / 398 sequences
# Processing: 305 / 398 sequences
# Processing: 306 / 398 sequences
# Processing: 307 / 398 sequences
# Processing: 308 / 398 sequences
# Processing: 309 / 398 sequences
# Processing: 310 / 398 sequences
# Processing: 311 / 398 sequences
# Processing: 312 / 398 sequences
# Processing: 313 / 398 sequences
# Processing: 314 / 398 sequences
# Processing: 315 / 398 sequences
# Processing: 316 / 398 sequences
# Processing: 317 / 398 sequences
# Processing: 318 / 398 sequences
# Processing: 319 / 398 sequences
# Processing: 320 / 398 sequences
# Processing: 321 / 398 sequences
# Processing: 322 / 398 sequences
# Processing: 323 / 398 sequences
# Processing: 324 / 398 sequences
# Processing: 325 / 398 sequences
# Processing: 326 / 398 sequences
# Processing: 327 / 398 sequences
# Processing: 328 / 398 sequences
# Processing: 329 / 398 sequences
# Processing: 330 / 398 sequences
# Processing: 331 / 398 sequences
# Processing: 332 / 398 sequences
# Processing: 333 / 398 sequences
# Processing: 334 / 398 sequences
# Processing: 335 / 398 sequences
# Processing: 336 / 398 sequences
# Processing: 337 / 398 sequences
# Processing: 338 / 398 sequences
# Processing: 339 / 398 sequences
# Processing: 340 / 398 sequences
# Processing: 341 / 398 sequences
# Processing: 342 / 398 sequences
# Processing: 343 / 398 sequences
# Processing: 344 / 398 sequences
# Processing: 345 / 398 sequences
# Processing: 346 / 398 sequences
# Processing: 347 / 398 sequences
# Processing: 348 / 398 sequences
# Error processing ENST00000310771: index out of range in self
# Processing: 349 / 398 sequences
# Processing: 350 / 398 sequences
# Processing: 351 / 398 sequences
# Processing: 352 / 398 sequences
# Error processing ENST00000444874: index out of range in self
# Processing: 353 / 398 sequences
# Processing: 354 / 398 sequences
# Processing: 355 / 398 sequences
# Processing: 356 / 398 sequences
# Processing: 357 / 398 sequences
# Processing: 358 / 398 sequences
# Processing: 359 / 398 sequences
# Error processing ENST00000695706: index out of range in self
# Processing: 360 / 398 sequences
# Error processing ENST00000695704: index out of range in self
# Processing: 361 / 398 sequences
# Error processing ENST00000695665: index out of range in self
# Processing: 362 / 398 sequences
# Processing: 363 / 398 sequences
# Processing: 364 / 398 sequences
# Error processing ENST00000429974: index out of range in self
# Processing: 365 / 398 sequences
# Processing: 366 / 398 sequences
# Processing: 367 / 398 sequences
# Processing: 368 / 398 sequences
# Processing: 369 / 398 sequences
# Error processing ENST00000610705: index out of range in self
# Processing: 370 / 398 sequences
# Processing: 371 / 398 sequences
# Error processing ENST00000655500: index out of range in self
# Processing: 372 / 398 sequences
# Error processing ENST00000553105: index out of range in self
# Processing: 373 / 398 sequences
# Error processing ENST00000641955: index out of range in self
# Processing: 374 / 398 sequences
# Processing: 375 / 398 sequences
# Error processing ENST00000737462: index out of range in self
# Processing: 376 / 398 sequences
# Processing: 377 / 398 sequences
# Processing: 378 / 398 sequences
# Processing: 379 / 398 sequences
# Error processing ENST00000806769: index out of range in self
# Processing: 380 / 398 sequences
# Processing: 381 / 398 sequences
# Processing: 382 / 398 sequences
# Processing: 383 / 398 sequences
# Processing: 384 / 398 sequences
# Processing: 385 / 398 sequences
# Processing: 386 / 398 sequences
# Error processing ENST00000623121: index out of range in self
# Processing: 387 / 398 sequences
# Error processing ENST00000594711: index out of range in self
# Processing: 388 / 398 sequences
# Error processing ENST00000624962: index out of range in self
# Processing: 389 / 398 sequences
# Error processing ENST00000591325: index out of range in self
# Processing: 390 / 398 sequences
# Error processing ENST00000445194: index out of range in self
# Processing: 391 / 398 sequences
# Processing: 392 / 398 sequences
# Processing: 393 / 398 sequences
# Processing: 394 / 398 sequences
# Processing: 395 / 398 sequences
# Processing: 396 / 398 sequences
# Processing: 397 / 398 sequences
# Processing: 398 / 398 sequences
# Error processing ENST00000458178: index out of range in self
